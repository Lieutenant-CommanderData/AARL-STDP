# %%
import mujoco as mj
import mujoco.viewer

model = mj.MjModel.from_xml_path('AltLegModels/MJ_Leg_MoreMuscles.xml')
data = mj.MjData(model)

viewer = mujoco.viewer.launch(model, data)

for i in range(8):
    print(data.sensordata[i])
# Out:
# 0.09491706187276543
# 0.0990438838262183
# 0.09491706187276543
# 0.0990438838262183
# 0.09483539995567
# 0.09896115828743222
# 0.09483539995567
# 0.09896115828743222
